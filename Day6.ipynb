# %% [markdown]
# ## 💻 Exercises: Day 6
#
# ### Exercises: Level 1

# %% [markdown]
# 1. Create an empty tuple
# 2. Create a tuple containing names of your sisters and your brothers (imaginary siblings are fine)
# 3. Join brothers and sisters tuples and assign it to siblings
# 4. How many siblings do you have?
# 5. Modify the siblings tuple and add the name of your father and mother and assign it to family_members

# %%
empty_tuple = ()
brothers = ('김기동', '김민겸')
sisters = ('홍서연', '안정현')
siblings = brothers + sisters
print("형제자매 수:", len(siblings))
family_members = siblings + ('김원조', '신현영')
print("가족:", family_members)
# Out:
# 형제자매 수: 4
# 가족: ('김기동', '김민겸', '홍서연', '안정현', '김원조', '신현영')

# %% [markdown]
# ### Exercises: Level 2

# %% [markdown]
# 1. Unpack siblings and parents from family_members
# 2. Create fruits, vegetables and animal products tuples. Join the three tuples and assign it to a variable called food_stuff_tp.
# 3. Change the about food_stuff_tp tuple to a food_stuff_lt list
# 4. Slice out the middle item or items from the food_stuff_tp tuple or food_stuff_lt list.
# 5. Slice out the first three items and the last three items from food_stuff_lt list
# 6. Delete the food_stuff_tp tuple completely
# 7. Check if an item exists in tuple:
#
# - Check if 'Estonia' is a nordic country
#
# - Check if 'Iceland' is a nordic country
#
# nordic_countries = ('Denmark', 'Finland','Iceland', 'Norway', 'Sweden')

# %%
*siblings_list, father, mother = family_members
print("형제자매:", siblings_list)
print("부모:", father, mother)

fruits = ('사과', '바나나')
vegetables = ('당근', '감자')
animal_products = ('우유', '고기')
food_stuff_tp = fruits + vegetables + animal_products
print("food tuple:", food_stuff_tp)
food_stuff_lt = list(food_stuff_tp)
print("food list:", food_stuff_lt)
mid = len(food_stuff_lt) // 2
print("가운데:", food_stuff_lt[mid])
print("앞 3개:", food_stuff_lt[:3])
print("뒤 3개:", food_stuff_lt[-3:])
del food_stuff_tp
try:
    print(food_stuff_tp)
except NameError:
    print("food_stuff_tp 삭제됨")

nordic_countries = ('Denmark', 'Finland','Iceland', 'Norway', 'Sweden')
print("Estonia 포함?", 'Estonia' in nordic_countries)
print("Iceland 포함?", 'Iceland' in nordic_countries)
# Out:
# 형제자매: ['김기동', '김민겸', '홍서연', '안정현']
# 부모: 김원조 신현영
# food tuple: ('사과', '바나나', '당근', '감자', '우유', '고기')
# food list: ['사과', '바나나', '당근', '감자', '우유', '고기']
# 가운데: 감자
# 앞 3개: ['사과', '바나나', '당근']
# 뒤 3개: ['감자', '우유', '고기']
# food_stuff_tp 삭제됨
# Estonia 포함? False
# Iceland 포함? True
