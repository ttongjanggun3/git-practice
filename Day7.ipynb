# %% [markdown]
# ## 💻 Exercises: Day 7

# %% [markdown]
# ### Exercises: Level 1

# %% [markdown]
# 1. Find the length of the set it_companies
# 2. Add 'Twitter' to it_companies
# 3. Insert multiple IT companies at once to the set it_companies
# 4. Remove one of the companies from the set it_companies
# 5. What is the difference between remove and discard

# %%
it_companies = {'Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon'}
print(f'회사의 개수: {len(it_companies)}')
it_companies.add('Twitter')
it_companies.update(['Tesla', 'Netflix', 'Samsung'])
it_companies.remove('IBM')
# Out:
# 회사의 개수: 7

# %% [markdown]
# remove는 요소가 없으면 error 발생
# discard는 요소가 없어도 그냥 무시

# %% [markdown]
# ### Exercises: Level 2

# %%
A = {19, 22, 24, 20, 25, 26}
B = {19, 22, 20, 25, 26, 24, 28, 27}
print("A ∪ B:", A.union(B))
print("A ∩ B:", A.intersection(B))
print("A is subset of B:", A.issubset(B))
print("A and B are disjoint:", A.isdisjoint(B))
print("A ∪ B:", A.union(B))
print("B ∪ A:", B.union(A))
print("Symmetric Difference:", A.symmetric_difference(B))
del A
del B
print("A, B deleted")
# Out:
# A ∪ B: {19, 20, 22, 24, 25, 26, 27, 28}
# A ∩ B: {19, 20, 22, 24, 25, 26}
# A is subset of B: True
# A and B are disjoint: False
# A ∪ B: {19, 20, 22, 24, 25, 26, 27, 28}
# B ∪ A: {19, 20, 22, 24, 25, 26, 27, 28}
# Symmetric Difference: {27, 28}
# A, B deleted

# %% [markdown]
# ### Exercises: Level 3

# %% [markdown]
# 1. Convert the ages to a set and compare the length of the list and the set, which one is bigger?
# 2. Explain the difference between the following data types: string, list, tuple and set
# 3. _I am a teacher and I love to inspire and teach people._ How many unique words have been used in the sentence? Use the split methods and set to get the unique words.

# %%
age = [22, 19, 24, 25, 26, 24, 25, 24]
print("리스트 길이:", len(age))
print("집합 길이:", len(set(age)))
sentence = "I am a teacher and I love to inspire and teach people"

words = sentence.lower().split()
unique_words = set(words)

print(f'unique word 개수: {len(unique_words)}')
# Out:
# 리스트 길이: 8
# 집합 길이: 5
# unique word 개수: 10

# %% [markdown]
# - List: 수정 가능, 순서 O, 중복 O
# - Tuple: 수정 불가, 순서 O, 중복 O
# - Set: 수정 가능, 순서 X, 중복 X
